# %%
import random
class NakliLLM:
    def __init__(self):
        print('LLM Created')
    
    def predict(self, prompt):
        response_list = [
        'Delhi is the capital of India',
        'IPL is a cricket league',
        'AI stands for Artificial Intelligence'
        ]
        return random.choice(response_list)

llm = NakliLLM()
llm.predict()
# Out:
# LLM Created
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 15
#      12         return random.choice(response_list)
#      14 llm = NakliLLM()
# ---> 15 llm.predict()
#
# TypeError: NakliLLM.predict() missing 1 required positional argument: 'prompt'

# %%
class NakliPromptTemplate:
    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables
    
    def formatMe(self, input_dict):
        return self.template.format(**input_dict)

prompt = NakliPromptTemplate(
    template= 'what is the {capital} of {country}',
    input_variables = ['capital', 'country']
)

prompt.formatMe({"country": "india"})
# Out:
# 'what is the capital of rajsitrha'

# %%
llm = NakliLLM()
prompt = NakliPromptTemplate(
    template= 'what is the {capital} of {country}',
    input_variables = ['capital', 'country']
).formatMe({"country": "india", 'capital': 'capital'})

llm.predict(prompt)
# Out:
# LLM Created
# 'Delhi is the capital of India'
